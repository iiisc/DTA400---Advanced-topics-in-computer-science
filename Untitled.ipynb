# %%
# Älgar föds och dör varje år
# X antal skjuts ihjäl varje år
# Vi varierar antalet skjutna älgar och ser vad som händer med matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline         
import simpy

SIM_TIME = 100
START_KALVAR = 1000 # Älgar räknas som kalvar under sitt första levnadsår
START_VUXNA = 5000 
global VUXNA_STAT
global KALV_STAT
VUXNA_STAT={}
KALV_STAT={}
d={1:'a'}
d={2:'b'}
for i in d:
    print(d[i])

class skogen(object):
    def __init__(self, env, antal_vuxna, antal_kalvar):
        self.env = env
        self.vuxna = antal_vuxna
        self.kalvar = antal_kalvar

    def __str__(self):
        VUXNA_STAT[self.env.now] = int(self.vuxna)
        KALV_STAT [self.env.now] = int(self.kalvar)

        return f'År: {self.env.now} - Antal vuxna: {int(self.vuxna)} - Antal kalvar: {int(self.kalvar)}'

    def addera(self):
        # Fjolårets kalvar flyttas upp till vuxengruppen
        self.vuxna += self.kalvar
        self.kalvar = 0
        # Här föds nya kalvar
        self.kalvar += (self.vuxna/2)
        return

    def minska(self):
        # Naturlig minskning varje år
        self.vuxna -= (self.vuxna/2.3)
        return

    def skjuta(self):
        # Avskjutning varje år
        return

def cykel(env):
    # Funktionen simulerar 1 år.
    while True:
        print(skog)
        skog.addera()
        skog.minska()
        skog.skjuta()
        yield env.timeout(1)


env = simpy.Environment()
skog = skogen(env, START_VUXNA, START_KALVAR)
env.process(cykel(env))
env.run(until=SIM_TIME)


plt.title("Vuxna Älgar")
plt.xlabel("Simulerade år")
plt.ylabel("Antal Älgar")           
plt.plot(VUXNA_STAT.keys(),VUXNA_STAT.values())
plt.plot(KALV_STAT.keys(),KALV_STAT.values())
#print(VUXNA_STAT)
# Out:
# b
# År: 0 - Antal vuxna: 5000 - Antal kalvar: 1000
# År: 1 - Antal vuxna: 3391 - Antal kalvar: 3000
# År: 2 - Antal vuxna: 3612 - Antal kalvar: 3195
# År: 3 - Antal vuxna: 3848 - Antal kalvar: 3404
# År: 4 - Antal vuxna: 4099 - Antal kalvar: 3626
# År: 5 - Antal vuxna: 4366 - Antal kalvar: 3862
# År: 6 - Antal vuxna: 4651 - Antal kalvar: 4114
# År: 7 - Antal vuxna: 4954 - Antal kalvar: 4382
# År: 8 - Antal vuxna: 5277 - Antal kalvar: 4668
# År: 9 - Antal vuxna: 5621 - Antal kalvar: 4973
# År: 10 - Antal vuxna: 5988 - Antal kalvar: 5297
# År: 11 - Antal vuxna: 6378 - Antal kalvar: 5642
# År: 12 - Antal vuxna: 6794 - Antal kalvar: 6010
# År: 13 - Antal vuxna: 7238 - Antal kalvar: 6402
# År: 14 - Antal vuxna: 7710 - Antal kalvar: 6820
